# %%
import pandas as pd

# %%
df=pd.read_csv('NuclearGeneration(bp-stats-review-2019-all-data).csv')
df
# Out:
#          1965      1966      1967       1968       1969       1970       1971  \
# 0    0.028963  0.038919  0.034620   0.207721   0.119700   0.234647   0.905000
# 1    0.000000  0.000000  0.000000   0.000000   0.000000   0.000000   0.000000
# 2    0.870968  1.314756  1.823352   2.984072   3.317392   5.193477   9.075903
# 3    0.899931  1.353675  1.857972   3.191793   3.437092   5.428124   9.980903
# 4    0.000000  0.000000  0.000000   0.000000   0.000000   0.000000   0.000000
# 5    0.000000  0.000000  0.000000   0.000000   0.000000   0.000000   0.000000
# 6    0.000000  0.000000  0.000000   0.000000   0.000000   0.000000   0.000000
# 7    0.000000  0.000000  0.000000   0.000000   0.000000   0.000000   0.000000
# 8    0.000000  0.000000  0.000000   0.000000   0.000000   0.000000   0.000000
# 9    0.000000  0.000000  0.000000   0.000000   0.000000   0.000000   0.000000
# 10   0.000000  0.000000  0.000000   0.000000   0.000000   0.000000   0.000000
# ...

# %%
df.columns
# Out:
# Index(['1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1974',
#        '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        'Contents 1973', 'Growth rate per annum 2007-17',
#        'Growth rate per annum 2018',
#        'Nuclear: Consumption* Million tonnes oil equivalent',
#        'Number of Records', 'Share 2018'],
#       dtype='object')

# %%
df['countries']=df['Nuclear: Consumption* Million tonnes oil equivalent']
df.head()
# Out:
#        1965      1966      1967      1968      1969      1970      1971  \
# 0  0.028963  0.038919  0.034620  0.207721  0.119700  0.234647  0.905000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.870968  1.314756  1.823352  2.984072  3.317392  5.193477  9.075903
# 3  0.899931  1.353675  1.857972  3.191793  3.437092  5.428124  9.980903
# 4  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#         1972       1974       1975  ...        2016        2017        2018  \
# 0   1.517000   3.146000   2.670000  ...   22.727094   22.720051   22.636377
# 1   0.000000   0.000000   0.000000  ...    2.391088    2.462520    3.074757
# 2  12.883658  27.147229  41.087996  ...  191.903628  191.726344  192.233230
# 3  14.400658  30.293229  43.757996  ...  217.021810  216.908916  217.944364
# 4   0.000000   0.232000   0.518000  ...    1.874689    1.377563    1.555099
#
# ...

# %%
df=df[['countries','1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1974',
       '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
       '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
       '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
       '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
       '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']]
df.head()
# Out:
#              countries      1965      1966      1967      1968      1969  \
# 0               Canada  0.028963  0.038919  0.034620  0.207721  0.119700
# 1               Mexico  0.000000  0.000000  0.000000  0.000000  0.000000
# 2                   US  0.870968  1.314756  1.823352  2.984072  3.317392
# 3  Total North America  0.899931  1.353675  1.857972  3.191793  3.437092
# 4            Argentina  0.000000  0.000000  0.000000  0.000000  0.000000
#
#        1970      1971       1972       1974  ...        2009        2010  \
# 0  0.234647  0.905000   1.517000   3.146000  ...   20.243705   20.371088
# 1  0.000000  0.000000   0.000000   0.000000  ...    2.376132    1.330326
# 2  5.193477  9.075903  12.883658  27.147229  ...  190.274600  192.207159
# 3  5.428124  9.980903  14.400658  30.293229  ...  212.894438  213.908572
# 4  0.000000  0.000000   0.000000   0.232000  ...    1.851609    1.631443
#
#          2011        2012        2013        2014        2015        2016  \
# ...

# %%
df[df.countries.str.contains('Total')==False]
# Out:
#                              countries      1965      1966      1967  \
# 0                               Canada  0.028963  0.038919  0.034620
# 1                               Mexico  0.000000  0.000000  0.000000
# 2                                   US  0.870968  1.314756  1.823352
# 4                            Argentina  0.000000  0.000000  0.000000
# 5                               Brazil  0.000000  0.000000  0.000000
# 6                                Chile  0.000000  0.000000  0.000000
# 7                             Colombia  0.000000  0.000000  0.000000
# 8                              Ecuador  0.000000  0.000000  0.000000
# 9                                 Peru  0.000000  0.000000  0.000000
# 10                   Trinidad & Tobago  0.000000  0.000000  0.000000
# 11                           Venezuela  0.000000  0.000000  0.000000
# 12                     Central America  0.000000  0.000000  0.000000
# 13                     Other Caribbean  0.000000  0.002715  0.008598
# ...

# %%
# making boolean series for a team name 
filter1 = data["Team"]=="Atlanta Hawks"
  
# making boolean series for age 
filter2 = data["Age"]>24
  
# filtering data on basis of both filters 
data.where(filter1 & filter2, inplace = True) 
  
# display 
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-568da3891e0d> in <module>
#       1 # making boolean series for a team name
# ----> 2 filter1 = data["Team"]=="Atlanta Hawks"
#       3
#       4 # making boolean series for age
#       5 filter2 = data["Age"]>24
#
# NameError: name 'data' is not defined

# %%
df.countries.str.contains('Total')

# %%
filter1= df['countries']!=df.countries.str.contains('Total')

# %%
df.countries.filter(like='^Total')

# %%
df.set_index('countries')

# %%
df1=df[df.countries.str.contains('Total')]
df1

# %%
#df.info()

# %%
#df.columns = pd.to_datetime(df.columns)

# %%
df.index=='Total*'

# %%
df = df[df.columns.drop(list(df.filter(regex='Test')))]
